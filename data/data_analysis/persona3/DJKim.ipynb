# %% [markdown]
# ## SETTINGS

# %%
# 폰트 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용
import matplotlib.font_manager as fm
# 설치된 폰트 중 'NanumGothic' 찾기
for font in fm.fontManager.ttflist:
    if 'NanumGothic' in font.name:
        plt.rcParams['font.family'] = font.name
        break
plt.rcParams['axes.unicode_minus'] = False
import seaborn as sns
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ## 2021년 시도별 사망자 통계

# %% [markdown]
# ### 데이터 로딩 및

# %%
df_death_statistics = pd.read_csv("../csv/2021년_월별_시도별_사망자통계.csv")

# %%
df_death_statistics = df_death_statistics.drop(index=0)
df_death_statistics = df_death_statistics.reset_index(drop=True)
df_death_statistics
# Out:
#          시점     전국 서울특별시 부산광역시 대구광역시 인천광역시 광주광역시 대전광역시 울산광역시 세종특별자치시   경기도  \
# 0   2021.01  27223  4095  2094  1289  1419   674   643   492     105  5774
# 1   2021.02  23787  3613  1804  1032  1210   602   620   425     111  5055
# 2   2021.03  26559  3938  1928  1245  1325   698   644   444     117  5629
# 3   2021.04  25071  3701  1826  1208  1318   627   631   448     103  5267
# 4   2021.05  25567  3977  1912  1113  1380   615   593   460     109  5434
# 5   2021.06  24381  3643  1735  1093  1297   623   630   443      93  5207
# 6   2021.07  25732  3958  1919  1185  1386   681   617   446     107  5554
# 7   2021.08  25918  3944  1960  1221  1306   652   721   470     115  5370
# 8   2021.09  25662  3921  1892  1203  1318   645   608   434      99  5362
# 9   2021.10  27750  4159  2024  1317  1421   722   666   478     131  5830
# 10  2021.11  28366  4488  2140  1310  1430   709   684   456     135  6013
# ...

# %%
df_death_statistics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 19 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시점       12 non-null     object
#  1   전국       12 non-null     object
#  2   서울특별시    12 non-null     object
#  3   부산광역시    12 non-null     object
#  4   대구광역시    12 non-null     object
#  5   인천광역시    12 non-null     object
#  6   광주광역시    12 non-null     object
#  7   대전광역시    12 non-null     object
#  8   울산광역시    12 non-null     object
#  9   세종특별자치시  12 non-null     object
#  10  경기도      12 non-null     object
#  11  강원특별자치도  12 non-null     object
#  12  충청북도     12 non-null     object
#  13  충청남도     12 non-null     object
#  14  전북특별자치도  12 non-null     object
#  15  전라남도     12 non-null     object
#  16  경상북도     12 non-null     object
#  17  경상남도     12 non-null     object
#  18  제주특별자치도  12 non-null     object
# dtypes: object(19)
# memory usage: 1.9+ KB

# %%
df_death_statistics
# Out:
#          시점       전국    서울특별시    부산광역시    대구광역시    인천광역시    광주광역시    대전광역시  \
# 0        시점  사망자수(명)  사망자수(명)  사망자수(명)  사망자수(명)  사망자수(명)  사망자수(명)  사망자수(명)
# 1   2021.01    27223     4095     2094     1289     1419      674      643
# 2   2021.02    23787     3613     1804     1032     1210      602      620
# 3   2021.03    26559     3938     1928     1245     1325      698      644
# 4   2021.04    25071     3701     1826     1208     1318      627      631
# 5   2021.05    25567     3977     1912     1113     1380      615      593
# 6   2021.06    24381     3643     1735     1093     1297      623      630
# 7   2021.07    25732     3958     1919     1185     1386      681      617
# 8   2021.08    25918     3944     1960     1221     1306      652      721
# 9   2021.09    25662     3921     1892     1203     1318      645      608
# 10  2021.10    27750     4159     2024     1317     1421      722      666
# ...
