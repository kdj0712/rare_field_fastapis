# %%
import pandas as pd
df_detail = pd.read_csv('./csv/질병분류코드별_진료내역_항목별_요양급여비용_현황_등록_후_12개월_2021.csv')
df_total = pd.read_csv('./csv/건강보험심사평가원_희귀질환 진료비 통계 2021.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
#       2 df_detail = pd.read_csv('./csv/질병분류코드별_진료내역_항목별_요양급여비용_현황_등록_후_12개월_2021.csv')
# ----> 3 df_total = pd.read_csv('./csv/건강보험심사평가원_희귀질환 진료비 통계 2021.csv')
#
# ...

# %%
# Out:
#      질병분류코드 및 질환별(1)              질병분류코드 및 질환별(2)       2021    2021.1  \
# 0    질병분류코드 및 질환별(1)              질병분류코드 및 질환별(2)          계       진찰료
# 1                  계                           소계  317789679  63604106
# 2               희귀질환                           소계  308572698  62306518
# 3               희귀질환             A81.0 크로이츠펠트-야콥병    1624857     73975
# 4               희귀질환      D12.6 M8220/0 가족성선종성폴립증     322142     25918
# ..               ...                          ...        ...       ...
# 722        기타염색체이상질환         Q93.5 16번 염색체 단완의 결손        326       271
# 723        기타염색체이상질환           Q93.2 18번 고리모양 염색체        492       211
# 724        기타염색체이상질환      Q92.7 18번 염색체 단완의 사염색체증       7104       903
# 725        기타염색체이상질환  Q99.8 X 염색체장완의 28부분의 중복 증후군       5423       547
# 726        기타염색체이상질환         Q93.7 재조합 8번 염색체 증후군       1780       510
#
#        2021.2   2021.3    2021.4   2021.5    2021.6  2021.7    2021.8  \
# ...
