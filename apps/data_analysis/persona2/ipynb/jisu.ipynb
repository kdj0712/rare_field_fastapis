# %%
import pandas as pd

# 첫 번째 파일 읽기
df_detail = pd.read_csv('./csv/질병분류코드별_진료내역_항목별_요양급여비용_현황_등록_후_12개월_2021.csv', header=1)

# 두 번째 파일 읽기
df_total = pd.read_csv('./csv/건강보험심사평가원_희귀질환 진료비 통계 2021.csv', encoding='CP949')

# %%
df_total
# Out:
#      진료년도 희귀질환 상병코드    환자수  명세서 청구건수  입내원일수        보험자부담금      요양급여비용총액
# 0    2021       D66   1671     31653  33590  134364000000  148528000000
# 1    2021       D67    389      6066   6461   50277576220   55536599090
# 2    2021       D70  14960     32471  56526   14622808620   16707794010
# 3    2021       D71    119       910   1839     638847540     690840100
# 4    2021       G10    324      1800  12292     991135350    1193086390
# ..    ...       ...    ...       ...    ...           ...           ...
# 388  2021     I4220   5472     20055  27301    3902452220    4374513880
# 389  2021     I4280    176       498    821     340054630     393817070
# 390  2021     I4982    567      1820   2572     866281300     960546820
# 391  2021     K0051    197       240    240       6994350      10008720
# 392  2021     L7322    774      4195   4629     394776660     711693410
#
# [393 rows x 7 columns]

# %%
rare_code = df_total['희귀질환 상병코드'].unique().tolist()

# %%
for x in rare_code :
    df_detail.loc[df_detail['질병분류코드 및 질환별(2)'].str.contains(x)]['희귀질환 상병코드']=x
# Out:
# /tmp/ipykernel_17924/2498286092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_detail.loc[df_detail['질병분류코드 및 질환별(2)'].str.contains(x)]['희귀질환 상병코드']=x
# /tmp/ipykernel_17924/2498286092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_detail.loc[df_detail['질병분류코드 및 질환별(2)'].str.contains(x)]['희귀질환 상병코드']=x
# /tmp/ipykernel_17924/2498286092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_detail.loc[df_detail['질병분류코드 및 질환별(2)'].str.contains(x)]['희귀질환 상병코드']=x
# /tmp/ipykernel_17924/2498286092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_detail.loc[df_detail['질병분류코드 및 질환별(2)'].str.contains(x)]['희귀질환 상병코드']=x
# /tmp/ipykernel_17924/2498286092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_detail.loc[df_detail['질병분류코드 및 질환별(2)'].str.contains(x)]['희귀질환 상병코드']=x
# /tmp/ipykernel_17924/2498286092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_detail.loc[df_detail['질병분류코드 및 질환별(2)'].str.contains(x)]['희귀질환 상병코드']=x
